# %% [markdown]
# # WORLD HAPPINESS RECORD ANALYSIS 2021

# %% [markdown]
# This project focuses on analyzing the World Happiness Report 2021 dataset to understand the factors that influence happiness levels across different countries. The dataset includes various indicators such as GDP per capita, social support, healthy life expectancy, freedom to make life choices, generosity, and perceptions of corruption.
#
# The objective of this project is to explore how these factors contribute to a country's overall happiness score and to identify patterns or trends among the happiest and least happy nations. Using data analysis techniques, the project highlights key insights, comparisons between countries, and the impact of socio-economic conditions on well-being.
#
# Through visualization and statistical analysis, this project aims to provide a better understanding of global happiness and the elements that play a crucial role in improving quality of life.

# %% [markdown]
# # >Importing Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - pandas is for data manipulation
# - matplot and seaborn for visualization

# %% [markdown]
# # >Loading Dataset

# %%
df= pd.read_csv("project.csv")
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %% [markdown]
# # >Inspecting Data

# %%
df.head(10)
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe         7.842
# 1      Denmark         Western Europe         7.620
# 2  Switzerland         Western Europe         7.571
# 3      Iceland         Western Europe         7.554
# 4  Netherlands         Western Europe         7.464
# 5       Norway         Western Europe         7.392
# 6       Sweden         Western Europe         7.363
# 7   Luxembourg         Western Europe         7.324
# 8  New Zealand  North America and ANZ         7.277
# 9      Austria         Western Europe         7.268
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
# ...

# %%
df.tail(10)
# Out:
#     Country name            Regional indicator  Ladder score  \
# 139      Burundi            Sub-Saharan Africa         3.775
# 140        Yemen  Middle East and North Africa         3.658
# 141     Tanzania            Sub-Saharan Africa         3.623
# 142        Haiti   Latin America and Caribbean         3.615
# 143       Malawi            Sub-Saharan Africa         3.600
# 144      Lesotho            Sub-Saharan Africa         3.512
# 145     Botswana            Sub-Saharan Africa         3.467
# 146       Rwanda            Sub-Saharan Africa         3.415
# 147     Zimbabwe            Sub-Saharan Africa         3.145
# 148  Afghanistan                    South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 139                           0.107         3.985         3.565
# 140                           0.070         3.794         3.521
# 141                           0.071         3.762         3.485
# ...

# %%
df.sample()
# Out:
#    Country name Regional indicator  Ladder score  \
# 80     Malaysia     Southeast Asia         5.384
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 80                           0.049          5.48         5.289
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 80                 10.238           0.817                   67.102
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 80                         0.895       0.125                      0.839
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 80                      2.43                             1.259
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 80                         0.797                                  0.587
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 80                                       0.624                      0.27
#
# ...

# %%
df.dtypes # check the column data type
# Out:
# Country name                                      str
# Regional indicator                                str
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# ...

# %%
df.columns # display column names
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='str')

# %%
df.shape # check the column data type
# Out:
# (149, 20)

# %%
df.info() # provides concise summary of a DataFrame's structure
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    str
#  1   Regional indicator                          149 non-null    str
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
#  9   Freedom to make life choices                149 non-null    float64
# ...

# %% [markdown]
# ## key insights from df.info()
#
# - No missing values
# - All 149 entries are complete across 18 columns
# - 16 out of 18 columns are float64
# - country and regional indicator are object types
# - data set is already clean

# %% [markdown]
# # >Selecting single column

# %%
# single column

df['Country name']
# Out:
# 0          Finland
# 1          Denmark
# 2      Switzerland
# 3          Iceland
# 4      Netherlands
#           ...
# 144        Lesotho
# 145       Botswana
# 146         Rwanda
# 147       Zimbabwe
# 148    Afghanistan
# Name: Country name, Length: 149, dtype: str

# %%
df['Regional indicator']
# Out:
# 0          Western Europe
# 1          Western Europe
# 2          Western Europe
# 3          Western Europe
# 4          Western Europe
#               ...
# 144    Sub-Saharan Africa
# 145    Sub-Saharan Africa
# 146    Sub-Saharan Africa
# 147    Sub-Saharan Africa
# 148            South Asia
# Name: Regional indicator, Length: 149, dtype: str

# %% [markdown]
# # >Selecting multiple columns

# %%
# multiple column

df[['Social support','Generosity']]
# Out:
#      Social support  Generosity
# 0             0.954      -0.098
# 1             0.954       0.030
# 2             0.942       0.025
# 3             0.983       0.160
# 4             0.942       0.175
# ..              ...         ...
# 144           0.787      -0.131
# 145           0.784      -0.246
# 146           0.552       0.061
# 147           0.750      -0.047
# 148           0.463      -0.102
#
# [149 rows x 2 columns]

# %% [markdown]
# # >Filtering data

# %%
df[df['Ladder score']>6] # helps identify the happiest countries
# Out:
#                 Country name                  Regional indicator  \
# 0                    Finland                      Western Europe
# 1                    Denmark                      Western Europe
# 2                Switzerland                      Western Europe
# 3                    Iceland                      Western Europe
# 4                Netherlands                      Western Europe
# 5                     Norway                      Western Europe
# 6                     Sweden                      Western Europe
# 7                 Luxembourg                      Western Europe
# 8                New Zealand               North America and ANZ
# 9                    Austria                      Western Europe
# 10                 Australia               North America and ANZ
# 11                    Israel        Middle East and North Africa
# 12                   Germany                      Western Europe
# ...

# %%
df[df['Ladder score']<3] # Useful for comparing low-performing regions
# Out:
#     Country name Regional indicator  Ladder score  \
# 148  Afghanistan         South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 148                      2.43                              0.37
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 148                           0.0                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 148                                         0.0                     0.122
#
# ...

# %%
df[df['Country name']=='Switzerland']
# Out:
#   Country name Regional indicator  Ladder score  \
# 2  Switzerland     Western Europe         7.571
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 2                           0.036         7.643           7.5
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 2                 11.117           0.942                     74.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 2                         0.919       0.025                      0.292
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 2                      2.43                             1.566
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 2                         1.079                                  0.816
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 2                                       0.653                     0.204
#
# ...

# %%
df[df['lowerwhisker']<4]
# Out:
#      Country name            Regional indicator  Ladder score  \
# 135          Togo            Sub-Saharan Africa         4.107
# 136        Zambia            Sub-Saharan Africa         4.073
# 137  Sierra Leone            Sub-Saharan Africa         3.849
# 138         India                    South Asia         3.819
# 139       Burundi            Sub-Saharan Africa         3.775
# 140         Yemen  Middle East and North Africa         3.658
# 141      Tanzania            Sub-Saharan Africa         3.623
# 142         Haiti   Latin America and Caribbean         3.615
# 143        Malawi            Sub-Saharan Africa         3.600
# 144       Lesotho            Sub-Saharan Africa         3.512
# 145      Botswana            Sub-Saharan Africa         3.467
# 146        Rwanda            Sub-Saharan Africa         3.415
# 147      Zimbabwe            Sub-Saharan Africa         3.145
# 148   Afghanistan                    South Asia         2.523
#
# ...

# %%
df[df['Regional indicator']=='South Asia']
# Out:
#     Country name Regional indicator  Ladder score  \
# 86         Nepal         South Asia         5.269
# 88      Maldives         South Asia         5.198
# 100   Bangladesh         South Asia         5.025
# 104     Pakistan         South Asia         4.934
# 128    Sri Lanka         South Asia         4.325
# 138        India         South Asia         3.819
# 148  Afghanistan         South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 86                            0.070         5.406         5.132
# 88                            0.072         5.339         5.057
# 100                           0.046         5.115         4.934
# 104                           0.068         5.066         4.802
# 128                           0.066         4.454         4.196
# 138                           0.026         3.869         3.769
# 148                           0.038         2.596         2.449
#
# ...

# %% [markdown]
# # >Filtering with multiple conditions

# %%
df[(df['Regional indicator']=='South Asia')&(df['lowerwhisker']>5.000)]
# Out:
#    Country name Regional indicator  Ladder score  \
# 86        Nepal         South Asia         5.269
# 88     Maldives         South Asia         5.198
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 86                           0.070         5.406         5.132
# 88                           0.072         5.339         5.057
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 86                  8.120           0.774                   64.233
# 88                  9.826           0.913                   70.600
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 86                         0.782       0.152                      0.727
# 88                         0.854       0.024                      0.825
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 86                      2.43                             0.519
# 88                      2.43                             1.115
#
# ...

# %%
df[(df['Logged GDP per capita']>10)&(df['Ladder score']<5)] # Finds countries where wealth ≠ happiness
# Out:
#     Country name            Regional indicator  Ladder score  \
# 103       Turkey  Middle East and North Africa         4.948
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 103                           0.046         5.038         4.857
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 103                  10.24           0.822                   67.199
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 103                         0.576      -0.139                      0.776
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 103                      2.43                              1.26
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 103                         0.809                                   0.59
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# ...

# %% [markdown]
# # >Selecting Rows

# %%
df.iloc[9] # single rows
# Out:
# Country name                                         Austria
# Regional indicator                            Western Europe
# Ladder score                                           7.268
# Standard error of ladder score                         0.036
# upperwhisker                                           7.337
# lowerwhisker                                           7.198
# Logged GDP per capita                                 10.906
# Social support                                         0.934
# Healthy life expectancy                                 73.3
# Freedom to make life choices                           0.908
# Generosity                                             0.042
# Perceptions of corruption                              0.481
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.492
# Explained by: Social support                           1.062
# ...

# %%
df.iloc[4:11] # portion
# Out:
#    Country name     Regional indicator  Ladder score  \
# 4   Netherlands         Western Europe         7.464
# 5        Norway         Western Europe         7.392
# 6        Sweden         Western Europe         7.363
# 7    Luxembourg         Western Europe         7.324
# 8   New Zealand  North America and ANZ         7.277
# 9       Austria         Western Europe         7.268
# 10    Australia  North America and ANZ         7.183
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 4                            0.027         7.518         7.410
# 5                            0.035         7.462         7.323
# 6                            0.036         7.433         7.293
# 7                            0.037         7.396         7.252
# 8                            0.040         7.355         7.198
# 9                            0.036         7.337         7.198
# 10                           0.041         7.265         7.102
#
# ...

# %% [markdown]
# # >Rename Column

# %%
df.rename(columns={"Country name":"Country","Logged GDP per capita":"gdp_per_capita"},inplace=True)

# %%
df.head()
# Out:
#        Country Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  gdp_per_capita  \
# 0                           0.032         7.904         7.780          10.775
# 1                           0.035         7.687         7.552          10.933
# 2                           0.036         7.643         7.500          11.117
# 3                           0.059         7.670         7.438          10.878
# 4                           0.027         7.518         7.410          10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# ...

# %%
df['Ladder score'].value_counts()
# Out:
# Ladder score
# 5.929    2
# 5.477    2
# 7.842    1
# 7.620    1
# 7.571    1
#         ..
# 3.512    1
# 3.467    1
# 3.415    1
# 3.145    1
# 2.523    1
# Name: count, Length: 147, dtype: int64

# %% [markdown]
# # >Data Cleaning

# %% [markdown]
# ##

# %% [markdown]
# ## -Clean Numerical Columns with Characters

# %% [markdown]
# ###       this step is not needed because the data set is already very clean
# -No missing values → every column has 149/149 entries
# -No duplicate rows → duplicates = 0
# -Correct data types → numerical columns are float, text columns are object
# -Structured format → columns are clearly labeled and consistent

# %% [markdown]
# # >Droping Columns

# %%
df.drop(columns=['Ladder score in Dystopia'],inplace=True)

# %%
df.head()
# Out:
#        Country Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  gdp_per_capita  \
# 0                           0.032         7.904         7.780          10.775
# 1                           0.035         7.687         7.552          10.933
# 2                           0.036         7.643         7.500          11.117
# 3                           0.059         7.670         7.438          10.878
# 4                           0.027         7.518         7.410          10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# ...

# %%
df.drop(columns=['Standard error of ladder score'],inplace=True)

# %%
df.head()
# Out:
#        Country Regional indicator  Ladder score  upperwhisker  lowerwhisker  \
# 0      Finland     Western Europe         7.842         7.904         7.780
# 1      Denmark     Western Europe         7.620         7.687         7.552
# 2  Switzerland     Western Europe         7.571         7.643         7.500
# 3      Iceland     Western Europe         7.554         7.670         7.438
# 4  Netherlands     Western Europe         7.464         7.518         7.410
#
#    gdp_per_capita  Social support  Healthy life expectancy  \
# 0          10.775           0.954                     72.0
# 1          10.933           0.954                     72.7
# 2          11.117           0.942                     74.4
# 3          10.878           0.983                     73.0
# 4          10.932           0.942                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 18 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     149 non-null    str
#  1   Regional indicator                          149 non-null    str
#  2   Ladder score                                149 non-null    float64
#  3   upperwhisker                                149 non-null    float64
#  4   lowerwhisker                                149 non-null    float64
#  5   gdp_per_capita                              149 non-null    float64
#  6   Social support                              149 non-null    float64
#  7   Healthy life expectancy                     149 non-null    float64
#  8   Freedom to make life choices                149 non-null    float64
#  9   Generosity                                  149 non-null    float64
# ...

# %% [markdown]
# # >Handling missing values

# %%
df.isnull().sum()
# Out:
# Country                                       0
# Regional indicator                            0
# Ladder score                                  0
# upperwhisker                                  0
# lowerwhisker                                  0
# gdp_per_capita                                0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# dtype: int64

# %% [markdown]
# -How to fill missing values
#
# numerical - fill with median
#
#
# categorical - fill with mode
#
#
# df['column_name].mode()
#
#
# df['column_name].median()

# %% [markdown]
# # > Droping Rows

# %% [markdown]
# df.dropna(subset=['column_name','column_name'],inplace=True)

# %% [markdown]
# # >Handling Duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #if duplicate exist we can drop the column
#
#
# print('Before:',df_clean.shape)
#
# df_clean=df_clean.drop_duplicates()
#
# print('After:',df_clean.shape)

# %%
df.shape
# Out:
# (149, 18)

# %%
df.head()
# Out:
#        Country Regional indicator  Ladder score  upperwhisker  lowerwhisker  \
# 0      Finland     Western Europe         7.842         7.904         7.780
# 1      Denmark     Western Europe         7.620         7.687         7.552
# 2  Switzerland     Western Europe         7.571         7.643         7.500
# 3      Iceland     Western Europe         7.554         7.670         7.438
# 4  Netherlands     Western Europe         7.464         7.518         7.410
#
#    gdp_per_capita  Social support  Healthy life expectancy  \
# 0          10.775           0.954                     72.0
# 1          10.933           0.954                     72.7
# 2          11.117           0.942                     74.4
# 3          10.878           0.983                     73.0
# 4          10.932           0.942                     72.4
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 18 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     149 non-null    str
#  1   Regional indicator                          149 non-null    str
#  2   Ladder score                                149 non-null    float64
#  3   upperwhisker                                149 non-null    float64
#  4   lowerwhisker                                149 non-null    float64
#  5   gdp_per_capita                              149 non-null    float64
#  6   Social support                              149 non-null    float64
#  7   Healthy life expectancy                     149 non-null    float64
#  8   Freedom to make life choices                149 non-null    float64
#  9   Generosity                                  149 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Regional indicator', 'Ladder score', 'upperwhisker',
#        'lowerwhisker', 'gdp_per_capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Explained by: Log GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='str')

# %% [markdown]
# # >Saving Data to a File

# %%
# save the survivors to a new csv file

df.to_csv('project_cleaned.csv',index=False)

# %%
df_new=pd.read_csv("project_cleaned.csv")
df_new
# Out:
#          Country  Regional indicator  Ladder score  upperwhisker  \
# 0        Finland      Western Europe         7.842         7.904
# 1        Denmark      Western Europe         7.620         7.687
# 2    Switzerland      Western Europe         7.571         7.643
# 3        Iceland      Western Europe         7.554         7.670
# 4    Netherlands      Western Europe         7.464         7.518
# ..           ...                 ...           ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512         3.748
# 145     Botswana  Sub-Saharan Africa         3.467         3.611
# 146       Rwanda  Sub-Saharan Africa         3.415         3.548
# 147     Zimbabwe  Sub-Saharan Africa         3.145         3.259
# 148  Afghanistan          South Asia         2.523         2.596
#
#      lowerwhisker  gdp_per_capita  Social support  Healthy life expectancy  \
# 0           7.780          10.775           0.954                   72.000
# ...

# %% [markdown]
# # >Summary Statistics

# %%
df_new.columns
# Out:
# Index(['Country', 'Regional indicator', 'Ladder score', 'upperwhisker',
#        'lowerwhisker', 'gdp_per_capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Explained by: Log GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='str')

# %% [markdown]
# ## -Average(mean)

# %%
print("Ladder score - ",df_new['Ladder score'].mean())
print("gdp_per_capita - ",df_new['gdp_per_capita'].mean())
print("Social support - ",df_new['Social support'].mean())
print("upperwhisker - ",df_new['upperwhisker'].mean())
print("lowerwhisker - ",df_new['lowerwhisker'].mean())
# Out:
# Ladder score -  5.532838926174497
# gdp_per_capita -  9.432208053691276
# Social support -  0.8147449664429529
# upperwhisker -  5.648006711409396
# lowerwhisker -  5.4176308724832225

# %% [markdown]
# ## -Median

# %%
print("Ladder score - ",df_new['Ladder score'].median())
print("gdp_per_capita - ",df_new['gdp_per_capita'].median())
print("Social support - ",df_new['Social support'].median())
print("upperwhisker - ",df_new['upperwhisker'].median())
print("lowerwhisker - ",df_new['lowerwhisker'].median())
# Out:
# Ladder score -  5.534
# gdp_per_capita -  9.569
# Social support -  0.832
# upperwhisker -  5.625
# lowerwhisker -  5.413

# %% [markdown]
# ## -Mode

# %%
print("Regional indicator - ",df_new['Regional indicator'].mode())
# Out:
# Regional indicator -  0    Sub-Saharan Africa
# Name: Regional indicator, dtype: str

# %% [markdown]
# ## -Standard deviation

# %%
print("Ladder score - ",df_new['Ladder score'].std())
print("gdp_per_capita - ",df_new['gdp_per_capita'].std())
print("Social support - ",df_new['Social support'].std())
print("upperwhisker - ",df_new['upperwhisker'].std())
print("lowerwhisker - ",df_new['lowerwhisker'].std())
# Out:
# Ladder score -  1.073923565823598
# gdp_per_capita -  1.1586014476640767
# Social support -  0.11488902720653997
# upperwhisker -  1.0543296223939433
# lowerwhisker -  1.0948790526132375

# %%
df_new.select_dtypes(include='number').std()
# Out:
# Ladder score                                  1.073924
# upperwhisker                                  1.054330
# lowerwhisker                                  1.094879
# gdp_per_capita                                1.158601
# Social support                                0.114889
# Healthy life expectancy                       6.762043
# Freedom to make life choices                  0.113332
# Generosity                                    0.150657
# Perceptions of corruption                     0.179226
# Explained by: Log GDP per capita              0.404740
# Explained by: Social support                  0.258871
# Explained by: Healthy life expectancy         0.213019
# Explained by: Freedom to make life choices    0.137888
# Explained by: Generosity                      0.098270
# Explained by: Perceptions of corruption       0.114361
# Dystopia + residual                           0.537645
# dtype: float64

# %%
df_new.describe()
# Out:
#        Ladder score  upperwhisker  lowerwhisker  gdp_per_capita  \
# count    149.000000    149.000000    149.000000      149.000000
# mean       5.532839      5.648007      5.417631        9.432208
# std        1.073924      1.054330      1.094879        1.158601
# min        2.523000      2.596000      2.449000        6.635000
# 25%        4.852000      4.991000      4.706000        8.541000
# 50%        5.534000      5.625000      5.413000        9.569000
# 75%        6.255000      6.344000      6.128000       10.421000
# max        7.842000      7.904000      7.780000       11.647000
#
#        Social support  Healthy life expectancy  Freedom to make life choices  \
# count      149.000000               149.000000                    149.000000
# mean         0.814745                64.992799                      0.791597
# std          0.114889                 6.762043                      0.113332
# min          0.463000                48.478000                      0.382000
# ...

# %% [markdown]
# # Key Insights
#
# - all columns have 149 values(countries)
# - no missing values
# - data is very clean
# - mean and median are the same or very close
# - the data is evenly spread on both sides(like a bell shape)
# - mean is 5.53 most countries fall in a moderate happiness range,not       extremely high or low
# -

# %%
df_new.describe(include=object)
# Out:
# C:\Users\ic\AppData\Local\Temp\ipykernel_15736\2331272144.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df_new.describe(include=object)
#         Country  Regional indicator
# count       149                 149
# unique      149                  10
# top     Finland  Sub-Saharan Africa
# freq          1                  36

# %% [markdown]
# # Key Insights

# %% [markdown]
# - No missing values in both Country and Regional indicator columns
# - All country names are unique (149 unique)
# - All country names are unique (149 unique)
# - Only 10 unique regions → Countries are grouped into a limited number of regional categories.
# - Most frequent region: Sub-Saharan Africa (36 countries) → This region has the highest representation in the dataset.
# - Top country = Finland → This just means Finland appears first or is most common alphabetically—not meaningful since all countries occur only once.

# %% [markdown]
# # >DATA VISUALIZATION

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ###  # Histogram

# %% [markdown]
# - ### Distribution of continues numerical data

# %%
df_num= df_new.copy()
df_num.drop(columns=['Regional indicator','Country'],inplace=True)
df_num.hist(figsize=(40,40),bins=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### # INSIGHTS
#
# - From the Ladder Score histogram:There are very few extremely happy or unhappy countries—most are moderately happy.
# - The global average happiness ≈ 5.5, showing moderate happiness worldwide.(Histogram peak is around 5 – 6)
# - GDP is uneven, but happiness is more balanced →
# Higher GDP does NOT always guarantee higher happiness.
# - Some countries achieve moderate happiness despite low GDP, proving other factors matter.
# - Since most countries have high social support, it strongly contributes to maintaining moderate-to-high happiness levels.(Values concentrated at high end (0.7–1.0))
# - A group of countries have very strong social systems, which aligns with top happiness nations.(Histogram shows clustering near 0.9–1.0)
# - Countries with higher life expectancy tend to fall in higher happiness ranges.(Concentrated around 60–75 years)
# - Most countries report good freedom levels, supporting overall happiness.(Skewed toward higher values (0.6–0.9))
# - Lower corruption perception  is common →
# This supports higher happiness levels.
# - Region with Highest Happiness:High clustering of High Social support,High freedom,High GDP (few countries)
#   These patterns indicate that developed regions (like Europe) dominate higher happiness levels.

# %% [markdown]
# # DAY 6

# %% [markdown]
# ### # Box Plot

# %%
plt.figure(figsize=(4,4))
sns.boxplot(data=df_new,x="Ladder score")
plt.title("Distribution of Ladder score")
plt.xlabel("Ladder score")
plt.ylabel("Count")
plt.show()

# %%
for col in df_num.columns:
    plt.figure(figsize=(6,4))
    plt.boxplot(df_num[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# #### INSIGHTS
#
# -  Ladder score has median approximately 5.5 to 6.5 with lower outliers on the left tail.
#
# -  Logged GDP per capita shows near-symmetric distribution with moderate interquartile range and no extreme outliers.
#
# - Social support has higher median value with shorter lower quartile range and minimal outliers on low end.
#
# - Healthy life expectancy displays bimodal distribution with two distinct median clusters across observations.
#
# - Freedom to make life choices shows compressed interquartile range concentrated in upper quartiles with few lower outliers.
#
# - Generosity has very low median with negative skew and long upper tail containing multiple high outliers.
#
# - Perceptions of corruption displays wide interquartile range indicating high variance across all observations.
#
# - Ladder score in Dystopia has zero variance with median, quartiles, and all values equal to constant 2.43.
#
# - Dystopia plus residual shows median around 2.0 with symmetrical spread and moderate variance both directions.
#
# - Ladder score's lower outliers represent observations falling below Dystopia baseline despite adequate GDP.
#
# - Social support's compact upper quartile aligns with Ladder score's happiest observations showing strong covariance.
#
# - Perceptions of corruption's lower quartile outliers correspond to happier Ladder score observations.
#
# - Freedom's narrow interquartile range suggests low variance with most observations clustering near median.
#
# - Dystopia plus residual exhibits both positive and negative residuals relative to baseline with mean near zero.

# %% [markdown]
# ### #KDE Plot

# %%
for col in df_num.columns:
    plt.figure(figsize=(6,4))
    sns.kdeplot(df_num[col],fill=True)
    plt.title(col)
    plt.show()

# %% [markdown]
# ### # INSIGHTS
#
# - Extreme happiness (very high/low) is rare, most countries cluster in the middle.(Peak around 5–6,Long, thin tails on both sides)
# - Global happiness is concentrated around ~5.5, confirming a moderate average.
# - GDP is Strong right skewed (long tail to the right) &Happiness is more centered and balanced.
# GDP is highly unequal, but happiness is not →
# Higher GDP does not always lead to proportionally higher happiness.
# - Many countries maintain decent happiness despite low income, highlighting non-economic influences.
# - Most countries have strong social support →
# This strongly supports stable happiness levels globally.(KDE peak near high values (0.8–1.0))
# - A group of countries consistently achieves very high social support, contributing to top happiness ranks.
# - Life expectancy Peak around 65–70 ,Similar pattern to happiness KDE.
#   Both variables follow similar distributions →
# Higher life expectancy aligns with higher happiness.
# - KDE curve is higher on the right side
# This means more countries have higher values,
# Higher value (closer to 1) = LOW corruption
# Lower value (closer to 0) = HIGH corruption
# Since the curve is concentrated on the higher side:
#
#    Most countries have lower corruption levels
# Only a few countries have very high corruption
# - Regions where variables like Social support,Freedom,Life expectancy peak (like developed regions) tend to have higher happiness concentrations.

# %% [markdown]
# ### # Pie Chart

# %%
import matplotlib.pyplot as plt

# Count occurrences of each category
counts = df_new["Regional indicator"].value_counts()

plt.figure(figsize=(4,4))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title("Distribution by Region")
plt.show()

# %% [markdown]
# ### # INSIGHTS
#
# - If a region has more countries, it has a higher chance of containing both top and bottom countries.
# Regions with larger representation show greater variation in happiness levels.
# - The global average happiness is influenced more by regions with more countries.
# - The global average happiness is influenced more by regions with more countries.
# - Low GDP but High Happiness:Certain regions may contain countries that outperform economically weaker conditions with higher happiness.
# - Regions with strong community structures (social support )may show higher happiness even if they are smaller in size.
# - Even if a region is small in the pie chart, it can still dominate in social support quality.
# - Regions with better healthcare systems tend to contribute more to higher happiness scores.
# - Some regions may have higher freedom levels, even if their slice is smaller.
# - Regions with lower corruption levels contribute positively to happiness, regardless of size.
# - The largest region in the pie chart is not necessarily the happiest—it only has more countries, not higher happiness.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ### # Scatter Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="gdp_per_capita", y="Ladder score") # numerical v/s numerical
plt.title("Ladder score vs gdp_per_capita")
plt.xlabel("gdp_per_apita")
plt.ylabel("Ladder score")
plt.show()

# %% [markdown]
# - Higher GDP per capita → Higher happiness (Ladder Score)
# - Most countries fall in the moderate happiness range

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="Ladder score", y="Social support") # numerical v/s numerical
plt.title("Ladder score vs Social support")
plt.xlabel("Ladder score")
plt.ylabel(" Social support")

plt.show()

# %% [markdown]
# - Points show a clear upward trend
# - As social support increases, happiness (Ladder score) increases

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="Ladder score", y="Healthy life expectancy") 
plt.title("Ladder score vs Healthy life expectancy")
plt.xlabel("Ladder score")
plt.ylabel("Healthy life expectancy")
plt.show()

# %% [markdown]
# - Points show an upward trend,
# As life expectancy increases, happiness increases

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="Ladder score", y="Freedom to make life choices") 
plt.title("Ladder score vs Freedom to make life choices")
plt.xlabel("Ladder score")
plt.ylabel("Freedom to make life choices")
plt.show()

# %% [markdown]
# - Points show a positive upward trend
# As freedom increases, happiness increases
# - Countries with more freedom tend to be happier

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="upperwhisker", y="gdp_per_capita") 
plt.title("upperwhisker vs gdp_per_capita")
plt.xlabel("upperwhisker")
plt.ylabel("gdp_per_capita")
plt.show()

# %% [markdown]
# - Points show a clear upward trend
# As GDP increases, upperwhisker also increases
# - Higher GDP → Higher potential maximum happiness

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="upperwhisker", y="Social support") 
plt.title("upperwhisker vs social support")
plt.xlabel("upperwhisker")
plt.ylabel("social support")
plt.show()

# %% [markdown]
# - Points show a clear upward trend
# - As social support increases, upperwhisker also increases
# Compared to other plots, this is fairly well aligned (less scattered)
# - Higher social support → Higher potential maximum happiness

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="upperwhisker", y="Healthy life expectancy") 
plt.title("upperwhisker vs Healthy life expectancy ")
plt.xlabel("upperwhisker")
plt.ylabel("Healthy life expectancy")
plt.show()

# %% [markdown]
# - Points show a clear upward trend
# - As life expectancy increases, upperwhisker increases
# The pattern is moderately tight (not too scattered)
# - igher life expectancy → Higher potential happiness

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="upperwhisker", y="Freedom to make life choices") 
plt.title("upperwhisker vs Freedom to make life choices")
plt.xlabel("upperwhisker")
plt.ylabel("Freedom to make life choices")

plt.show()

# %% [markdown]
# - Points show a moderate upward trend
# - As freedom increases, upperwhisker increases
# More scatter compared to GDP or social support plots
#
# - Higher freedom → Higher potential happiness (but not very strong)

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="lowerwhisker", y="Healthy life expectancy") 
plt.title("lowerwhisker vs Healthy life expectancy ")
plt.xlabel("lowerwhisker")
plt.ylabel("Healthy life expectancy")
plt.show()

# %% [markdown]
# - Points show an upward trend
# - As life expectancy increases, lowerwhisker also increases
# Better health raises the minimum level of happiness

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="lowerwhisker", y="Social support") 
plt.title("lowerwhisker vs social support")
plt.xlabel("lowerwhisker")
plt.ylabel("social support")
plt.show()

# %% [markdown]
# - Clear upward trend
# - As social support increases, lowerwhisker also increases
# Points are fairly well aligned (not too scattered)
# - Higher social support → Higher minimum (baseline) happiness

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="lowerwhisker", y="gdp_per_capita") 
plt.title("lowerwhisker vs gdp_per_capita")
plt.xlabel("lowerwhisker")
plt.ylabel("gdp_per_capita")
plt.show()

# %% [markdown]
# - Points show a positive upward trend
# - As GDP increases, lowerwhisker also increases
# Some spread exists, but trend is clear
# - Higher GDP → Higher minimum (baseline) happiness

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="lowerwhisker", y="Freedom to make life choices") 
plt.title("lowerwhisker vs Freedom to make life choices")
plt.xlabel("lowerwhisker")
plt.ylabel("Freedom to make life choices")

plt.show()

# %% [markdown]
# - Points show a moderate upward trend
# - As freedom increases, lowerwhisker increases
# More scattered compared to social support
# - Higher freedom → Higher minimum happiness (but not very strong)

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="gdp_per_capita", y="Social support") 
plt.title("gdp_per_capita vs social support")
plt.xlabel("gdp_per_capita")
plt.ylabel("Social support")
plt.show()

# %% [markdown]
# - Points show a moderate upward trend
# - As GDP increases, social support generally increases
# But there is visible spread (not perfectly aligned)
# - Wealthier countries tend to have better social support, but not always

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="gdp_per_capita", y="Healthy life expectancy") 
plt.title("gdp_per_capita vs Healthy life expectancy")
plt.xlabel("gdp_per_capita")
plt.ylabel("Healthy life expectancy")
plt.show()

# %% [markdown]
# - Points form a clear upward trend
# - as GDP increases, life expectancy increases
# The points are fairly tightly clustered
# - Higher GDP → Better health → Longer life expectancy

# %%
plt.figure(figsize=(4,4))
sns.scatterplot(data=df_new, x="Ladder score", y="Perceptions of corruption") 
plt.title("Ladder score vs Perceptions of corruption")
plt.xlabel("Ladder score")
plt.ylabel("Perceptions of corruption")
plt.show()

# %% [markdown]
# - Points show a slight to moderate upward trend
#
#
# -  As perception of corruption improves (less corruption), happiness increases
# Some scatter is present
#
#
#  - lower corruption → Higher happiness

# %% [markdown]
# ### # Bar Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Loop through all numerical columns
for col in df_num.columns:
    plt.figure(figsize=(10, 6))
    
    sns.barplot(
        x='Regional indicator',
        y=col,          # ✅ use the column from loop
        data=df,
        hue='Regional indicator',   # needed for palette
        palette='viridis',
        legend=False
    )
    
    plt.xticks(rotation=45)
    plt.title(f"Average {col} by Regional indicator", fontsize=14)
    plt.xlabel("Regional indicator")
    plt.ylabel(col)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##### # INSIGHTS
#
# - From Ladder Score by region:
#   One region will have the tallest bar (highest happiness)
# Another will have the shortest bar (lowest happiness)
# - Most regions have moderate happiness, supporting the global average (~5–6).
# - Regions with higher GDP generally have higher happiness,
# but some regions break this pattern → GDP is not the only factor.(Compare
# Regions with high GDP bars and Regions with high happiness bars)
# - Some regions achieve good happiness despite lower income, likely due to social or cultural factors.(Look for Region with lower GDP bar,But relatively higher happiness bar)
# - Social support is a key driver of happiness across regions.(Social support is a key driver of happiness across regions.)
# - Region with tallest social support bar likely contains top happiest countries.
# - Healthier regions tend to be happier regions.
# - Regions with more freedom generally report higher happiness levels.(Compare freedom bars vs happiness bars)
# - Regions with Low corruption (higher values in your dataset) Show higher happiness
#    Better governance → higher trust → higher happiness
# - Region with tallest Ladder Score bar Region with tallest Ladder Score bar

# %% [markdown]
# ## Multivariate

# %% [markdown]
# ### # Heat Map(Correlaion)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df_new[num_cols].corr(),
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# #### Correlation Heatmap – Key Insights
#
# - The heatmap shows correlation values from -1 to +1
# - +1 → strong positive relationship
# 0 → no relationship
# - -1 → strong negative relationship
# - Happiness (Ladder score) is most strongly influenced by:Social support(strongest),
# GDP per capita,
# Healthy life expectancy,
# Freedom to make life choices,
# Perceptions of corruption (negative effect).
# - Countries with high values in these variables have higher happiness scores(Strong positive correlation with:Social support,GDP,Health)
# - Global happiness is influenced by a combination of factors, not one alone
# - GDP increases happiness, but does not fully determine it
# - Other factors (especially social support) explain why some countries are still happy
# - Social support is the strongest predictor of happiness(Social support is the strongest predictor of happiness)
# - Countries with strong support systems perform well across multiple dimensions
# - Better health leads to higher life satisfaction(Strong positive correlation)
# - Freedom contributes to happiness but is less influential than support or GDP(Moderate positive correlation)
# - Lower corruption → Higher happiness(Negative relationship)
# - These regions dominate top happiness rankings(Regions with:High GDP,High support,High health)

# %% [markdown]
# ### # Reg Plot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.regplot(x='lowerwhisker',
            y='Ladder score',
            data=df_new)

plt.title('Regression Plot of Lowerwhisker vs Ladder Score')
plt.xlabel('Lowerwhisker')
plt.ylabel('Ladder Score')
plt.show()

# %% [markdown]
# - The regression line shows a strong upward trend
# - Points are closely aligned to the line
# - Higher lowerwhisker → Higher happiness (Ladder score)
# - Minimum happiness level strongly reflects overall happiness

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.regplot(x='upperwhisker',
            y='Ladder score',
            data=df_new)

plt.title('Regression Plot of upperwhisker vs Ladder Score')
plt.xlabel('upperwhisker')
plt.ylabel('Ladder Score')
plt.show()

# %% [markdown]
# - Very strong upward linear relationship
# - Points lie very close to the regression line
# - Higher upperwhisker → Higher actual happiness
# - Countries with higher potential happiness actually achieve higher happiness

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# This project analyzed the Global Happiness dataset to understand how different factors like GDP, social support, health, freedom, and corruption influence happiness levels across countries.
#
# The workflow included Data Cleaning (handling missing values, dropping irrelevant columns like region/country where needed),Data Transformation (selecting numerical features),Exploratory Data Analysis (EDA) using Histograms,Box plots,KDE plots,Scatter plots,Line plots (with limitations),Heatmap,Regression plots.
#
# Happiness is multi-dimensional and cannot be explained by income alone. While GDP provides the foundation for better living conditions, social support plays the most critical role in determining overall life satisfaction. Health and freedom further enhance well-being, while corruption negatively impacts it.
